# %% [markdown]
# #  and --> &_________________or --> |____________not --> ~___________isin

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill']>40
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill']>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df[df['sex']=='Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# and
df[(df['total_bill']>30)&(df['sex']=='Female')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3             14.77
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4              7.54
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
#
#          Payer Name         CC Number Payment ID
# 11     Diane Macias  4577817359320969    Sun6686
# 52     Emily Daniel  4291280793094374    Sun6165
# 85      Shawna Cook  6011787464177340   Thur7972
# 102   Heather Cohen   379771118886604    Sat6240
# 197     Brooke Soto  5544902205760175   Thur9313
# 219    Shelby House      502097403252    Sat8863
# ...

# %%
# not
df[(df['total_bill']>40) & ~(df['smoker']=='No')]
# df[(df['total_bill']>40) & (df['smoker']!='No')]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
#
#         Payer Name         CC Number Payment ID
# 95   Aaron Bentley   180026611638690    Fri9628
# 102  Heather Cohen   379771118886604    Sat6240
# 170  Gregory Clark  5473850968388236    Sat1954
# 182   Jose Parsons  4112207559459910    Sun2337
# 184    Stephen Cox  3547798222044029    Sun5140
# 197    Brooke Soto  5544902205760175   Thur9313

# %%
# or
df[(df['day']=='Sun') | (df['day']=='Thur')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# 205       16.47  3.23  Female    Yes  Thur   Lunch     3              5.49
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[((df['day']=='Sun') | (df['day']=='Thur')) & (df['sex']=='Female')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# 18        16.97  3.50  Female     No   Sun  Dinner     3              5.66
# 51        10.29  2.60  Female     No   Sun  Dinner     2              5.14
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 82        10.07  1.83  Female     No  Thur   Lunch     1             10.07
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 114       25.71  4.00  Female     No   Sun  Dinner     3              8.57
# ...

# %%
#isin
option=['Sat','Sun']
df[df['day'].isin(option)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # apply method

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df['CC Number'].apply(last_four)
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242    0950
# 243    8139
# Name: CC Number, Length: 244, dtype: object

# %%
df['total_bill'].mean()
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price<10:
        return '$'
    elif price>=10 and price<30:
        return '$$'
    else:
        return '$$$'

# %%
df['expencive']=df['total_bill'].apply(yelp)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID expencive
# 0  Christy Cunningham  3560325168603410    Sun2959        $$
# 1      Douglas Tucker  4478071379779230    Sun4608        $$
# 2      Travis Walters  6011812112971322    Sun4458        $$
# 3    Nathaniel Harris  4676137647685994    Sun5260        $$
# 4        Tonya Carter  4832732618637221    Sun2251        $$

# %% [markdown]
# # apply method with lambda function

# %%
#محاسبه مالیات صورت حساب
df['total_bill'].apply(lambda bill : bill* 0.18)
# Out:
# 0      3.0582
# 1      1.8612
# 2      3.7818
# 3      4.2624
# 4      4.4262
#         ...
# 239    5.2254
# 240    4.8924
# 241    4.0806
# 242    3.2076
# 243    3.3804
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill , tip):
    if tip/ total_bill >0.20:
        return 'Generuse'
    else:
        return 'other'

# %%
# one way
df['Quality']=df[['total_bill','tip']].apply(lambda df :quality(df['total_bill'], df['tip']),axis=1)

# %%
df.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
#
#            Payer Name         CC Number Payment ID   Quality
# 0  Christy Cunningham  3560325168603410    Sun2959     other
# 1      Douglas Tucker  4478071379779230    Sun4608     other
# 2      Travis Walters  6011812112971322    Sun4458     other
# 3    Nathaniel Harris  4676137647685994    Sun5260     other
# 4        Tonya Carter  4832732618637221    Sun2251     other
# ...

# %%
# other and faster way
df['Tip Quality']= np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
#
#            Payer Name         CC Number Payment ID expencive   Quality  \
# 0  Christy Cunningham  3560325168603410    Sun2959        $$     other
# 1      Douglas Tucker  4478071379779230    Sun4608        $$     other
# 2      Travis Walters  6011812112971322    Sun4458        $$     other
# 3    Nathaniel Harris  4676137647685994    Sun5260        $$     other
# ...

# %% [markdown]
# # describe & sort_values & corr & max , min , idxmax , idxmin & value_counts

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values('tip', ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sort_values(['tip' , 'size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
# for numerical values
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df[['total_bill' , 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
df['total_bill'].max()
# Out:
# 50.81

# %%
df['total_bill'].min()
# Out:
# 3.07

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
# for categorical values
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %% [markdown]
# # unique , nunique

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
df['size'].nunique()
# Out:
# 6

# %% [markdown]
# # replace

# %%
df['Quality']=df['Quality'].replace(to_replace='other', value='OK')

# %%
df.head(7)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
#
#            Payer Name         CC Number Payment ID   Quality
# 0  Christy Cunningham  3560325168603410    Sun2959        OK
# 1      Douglas Tucker  4478071379779230    Sun4608        OK
# 2      Travis Walters  6011812112971322    Sun4458        OK
# 3    Nathaniel Harris  4676137647685994    Sun5260        OK
# 4        Tonya Carter  4832732618637221    Sun2251        OK
# ...

# %% [markdown]
# # map

# %%
time={'Dinner':'D' , 'Lunch':'L'}
df['time']=df['time'].map(time)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun    D     2              8.49
# 1       10.34  1.66    Male     No  Sun    D     3              3.45
# 2       21.01  3.50    Male     No  Sun    D     3              7.00
# 3       23.68  3.31    Male     No  Sun    D     2             11.84
# 4       24.59  3.61  Female     No  Sun    D     4              6.15
#
#            Payer Name         CC Number Payment ID Quality
# 0  Christy Cunningham  3560325168603410    Sun2959      OK
# 1      Douglas Tucker  4478071379779230    Sun4608      OK
# 2      Travis Walters  6011812112971322    Sun4458      OK
# 3    Nathaniel Harris  4676137647685994    Sun5260      OK
# 4        Tonya Carter  4832732618637221    Sun2251      OK

# %% [markdown]
# # duplicated value

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
df['price_per_person'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239     True
# 240    False
# 241    False
# 242    False
# 243     True
# Name: price_per_person, Length: 244, dtype: bool

# %%
df['price_per_person'].duplicated().value_counts()
# df.drop_duplicates() --> for delete repeated amount
# Out:
# price_per_person
# False    217
# True      27
# Name: count, dtype: int64

# %% [markdown]
# # between & between_time

# %%
df['total_bill'].between(10 , 20 , inclusive='both')#left , right , both
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %% [markdown]
# # random sampling method

# %%
df.sample(7)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 137       14.15  2.00  Female     No  Thur   Lunch     2              7.08
# 217       11.59  1.50    Male    Yes   Sat  Dinner     2              5.80
# 134       18.26  3.25  Female     No  Thur   Lunch     2              9.13
# 136       10.33  2.00  Female     No  Thur   Lunch     2              5.16
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 189       23.10  4.00    Male    Yes   Sun  Dinner     3              7.70
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2              8.16
#
#           Payer Name         CC Number Payment ID
# 137   Vanessa Morris   213189344156819   Thur3890
# 217         Gary Orr    30324521283406    Sat8489
# 134  Karen Rodriguez     4952604748911     Thur75
# 136      Donna Kelly   180048553626376   Thur1393
# 2     Travis Walters  6011812112971322    Sun4458
# 189  Richard Stevens  3560193117506187    Sun1821
# ...

# %%
df.sample(frac=0.8)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 207       38.73  3.00    Male    Yes   Sat  Dinner     4              9.68
# 88        24.71  5.85    Male     No  Thur   Lunch     2             12.36
# 48        28.55  2.05    Male     No   Sun  Dinner     3              9.52
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2              7.90
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2              9.72
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 24        19.82  3.18    Male     No   Sat  Dinner     2              9.91
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2              8.00
# 164       17.51  3.00  Female    Yes   Sun  Dinner     2              8.76
# 83        32.68  5.00    Male    Yes  Thur   Lunch     2             16.34
# 130       19.08  1.50    Male     No  Thur   Lunch     2              9.54
#
#            Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# # nlargest & nsmallest

# %%
df.nlargest(5 , 'tip')
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00  Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590
# 23    Lance Peterson  3542584061609808     Sat239
# 59       Brian Ortiz  6596453823950595    Sat8139
# 141   Steven Carlson  3526515703718508   Thur1025

# %%
df.nsmallest(4 , 'price_per_person')
# Out:
#     total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 92        5.75  1.00  Female    Yes  Fri  Dinner     2              2.88
# 67        3.07  1.00  Female    Yes  Sat  Dinner     1              3.07
# 16       10.33  1.67  Female     No  Sun  Dinner     3              3.44
# 1        10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#           Payer Name         CC Number Payment ID
# 92      Leah Ramirez  3508911676966392    Fri3780
# 67     Tiffany Brock  4359488526995267    Sat3455
# 16  Elizabeth Foster  4240025044626033    Sun9715
# 1     Douglas Tucker  4478071379779230    Sun4608
