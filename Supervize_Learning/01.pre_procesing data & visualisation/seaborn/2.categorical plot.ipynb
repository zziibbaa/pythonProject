# %% [markdown]
# # توزیع داده های categorical

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('dm_office_sales.csv')
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %% [markdown]
# # countplot()

# %%
plt.figure(figsize=(10,6) ,dpi=150)
sns.countplot(data=df , x='division')
# Out:
# <Axes: xlabel='division', ylabel='count'>

# %%
plt.figure(figsize=(8,6) , dpi=150)
sns.countplot(data=df , x='level of education', hue='training level' )
sns.set()

# %% [markdown]
# # barplot()

# %%
plt.figure(figsize=(8,6) , dpi=150)
sns.barplot(data=df , x= 'level of education' , y='salary' , width=0.4 )
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %% [markdown]
# # estimator() by mean & errorbar() by confidence interval

# %%
plt.figure(figsize=(8,6) , dpi=200)
sns.barplot(data=df , x='level of education' , y='salary' , hue='division' , estimator=np.mean , errorbar=('ci' , 95))
# Out:
# <Axes: xlabel='level of education', ylabel='salary'>

# %% [markdown]
# # plt.legend()

# %%
plt.figure(figsize=(8,6) , dpi=200)
sns.barplot(data=df , x='level of education' , y='salary' , hue='division',alpha=0.8 )
plt.legend(bbox_to_anchor=(1.05, 0.25))

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#رفع هشدار خطا ها
import warnings
warnings.simplefilter(action='ignore' , category=FutureWarning)

# %% [markdown]
# # توزیع داده های دسته ای

# %% [markdown]
# ## boxplot() based on median

# %%
plt.figure(figsize=(11,3) , dpi=150)
sns.boxplot(data=df , x='parental level of education' , y='math score')
sns.set()

# %%
plt.figure(figsize=(11,3) , dpi=150 )
sns.boxplot(data=df , x='parental level of education' , y='math score' , hue='gender', sp)
plt.legend(bbox_to_anchor=(1.05,0.4) , borderaxespad=0 )

# %%
plt.figure(figsize=(6,5) , dpi=150)
sns.boxplot(data=df , x='math score' , y='parental level of education' , hue='gender', orient='h' , width=0.4)
# Out:
# <Axes: xlabel='math score', ylabel='parental level of education'>

# %% [markdown]
# # violinplot() complex of boxplot & distribution

# %%
plt.figure(figsize=(10,6) , dpi=150)
sns.violinplot(data=df , x='parental level of education' , y='math score')
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %% [markdown]
# # split vs dodge

# %%
plt.figure(figsize=(10,6) , dpi=150)
sns.violinplot(data=df , x='parental level of education' , y='math score' , hue='gender' , split=True)
# Out:
# <Axes: xlabel='parental level of education', ylabel='math score'>

# %% [markdown]
# # swarmplot

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=df , x='math score' )
# Out:
# <Axes: xlabel='math score'>

# %%
plt.figure(figsize=(7,5), dpi=150)
sns.swarmplot(data=df , x='race/ethnicity' , y='math score' , hue='gender' , dodge=True)
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='math score'>

# %% [markdown]
# # boxenplot()

# %% [markdown]
# ## به جای boxplotبرای داده های کوچکتر از 200 و بزرگتر از10000

# %%
plt.figure(figsize=(12,6))
sns.boxenplot(data=df , x='math score' , y='race/ethnicity')
# Out:
# <Axes: xlabel='math score', ylabel='race/ethnicity'>
