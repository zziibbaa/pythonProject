# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1=pd.read_csv('df1.csv')
df1=df1.set_index(['Unnamed: 0'])

# %%
df2=pd.read_csv('df2.csv')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %% [markdown]
# # hist plot with pandas

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
df1['A'].hist(bins=30)#defult=10
# Out:
# <Axes: >

# %% [markdown]
# # change style of plot

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')#bmh , dark_background , fivethirtyeight 
df1['A'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # area plot

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df2['a'].plot.area()
# Out:
# <Axes: >

# %% [markdown]
# # barplot

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# # line plot

# %%
df1.plot.line(y='B' , figsize=(12,3) , lw=0.5)
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %% [markdown]
# # scatter plot

# %%
df1.plot.scatter(x='A' , y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# # c char in pandas as hue in seaborn

# %%
df1.plot.scatter(x='A' , y='B', c='C' , cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# # s in pandas as s in seaborn

# %%
df1.plot.scatter(x='A' , y='B', s=df1['C']*100)
# Out:
# C:\Users\Ziba\anaconda3\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# # box plot

# %%
df2.plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # hexbin plot & gridsize

# %%
df=pd.DataFrame(np.random.randn(1000,2) , columns=['a','b'])
df.plot.hexbin(x='a' , y='b', gridsize=25)
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# # kde plot

# %%
df2.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df2['a'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3=pd.read_csv('df3.csv')
df3.plot.scatter(x='a', y='d', figsize=(15,4) , s=50 , c='red' , edgecolor='black' )
# Out:
# <Axes: xlabel='a', ylabel='d'>

# %%
df3['a'].hist(edgecolor='black')
# Out:
# <Axes: >

# %%
df3['a'].hist(bins=30 , edgecolor='white' , alpha=0.5)
# Out:
# <Axes: >

# %%
df3[['a' , 'b']].plot.box()
# Out:
# <Axes: >

# %%
df3['d'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
df3['d'].plot.density(linewidth=5 , linestyle=':')
# Out:
# <Axes: ylabel='Density'>

# %%
df3.iloc[:31].plot.area(alpha=0.5)
# Out:
# <Axes: >

# %%
f=plt.figure()
df3.iloc[:31].plot.area(alpha=0.6 , ax=f.gca())
plt.legend(loc='center left' , bbox_to_anchor=(1 , 0.5))
