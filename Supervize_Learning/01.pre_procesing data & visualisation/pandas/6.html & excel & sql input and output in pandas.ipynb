# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # input html in pandas

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/World_population')

# %%
len(tables)
# Out:
# 31

# %%
tables[1]
# Out:
#       Population         1     2     3     4     5     6     7     8     9  \
# 0           Year      1804  1927  1960  1974  1987  1999  2011  2022  2037
# 1  Years elapsed  200,000+   123    33    14    13    12    12    11    15
#
#      10
# 0  2057
# 1    20

# %%
tables[19]
# Out:
#   Population (in billions)   0.5  0.5.1     1   1.1     2   2.1     4   4.1  \
# 0                     Year  1500   1500  1804  1804  1927  1927  1974  1974
# 1            Years elapsed     —    304   304   123   123    47    47    48
#
#       8   8.1                                                 16  \
# 0  2022  2022  .mw-parser-output .tooltip-dotted{border-botto...
# 1    48    48                                                  —
#
#                                                 16.1
# 0  .mw-parser-output .tooltip-dotted{border-botto...
# 1                                                NaN

# %% [markdown]
# # out put html in pandas

# %%
tables[4].to_html('simple.html' , index=False)

# %% [markdown]
# # input excel in pandas

# %%
pd.read_excel('BCT.xlsx')# sheet_name='First_Sheet'
# Out:
#      Unnamed: 0        START  Gain/day  Unnamed: 3  سه ماه اول   سه ماه دوم  \
# 0           NaN   250.000000       1.0         NaN   618.27975  1513.939999
# 1           NaN          NaN       NaN         NaN         NaN          NaN
# 2           NaN          NaN       NaN         NaN         NaN          NaN
# 3           1.0   252.500000       1.0         NaN         NaN          NaN
# 4           2.0   255.025000       1.0         NaN         NaN          NaN
# ..          ...          ...       ...         ...         ...          ...
# 366       364.0  9352.335231       1.0         NaN         NaN          NaN
# 367       365.0  9445.858583       1.0         NaN         NaN          NaN
# 368       366.0  9540.317169       1.0         NaN         NaN          NaN
# 369       367.0  9635.720341       1.0         NaN         NaN          NaN
# 370       368.0  9732.077544       1.0         NaN         NaN          NaN
#
#       سه ماه سوم  سه ماه چهارم
# ...

# %%
pd.ExcelFile('BCT.xlsx').sheet_names
# Out:
# ['Sheet1']

# %%
excel_sheets=pd.read_excel('BCT.xlsx' , sheet_name=None)#type --> dict
excel_sheets
# Out:
# {'Sheet1':      Unnamed: 0        START  Gain/day  Unnamed: 3  سه ماه اول   سه ماه دوم  \
#  0           NaN   250.000000       1.0         NaN   618.27975  1513.939999
#  1           NaN          NaN       NaN         NaN         NaN          NaN
#  2           NaN          NaN       NaN         NaN         NaN          NaN
#  3           1.0   252.500000       1.0         NaN         NaN          NaN
#  4           2.0   255.025000       1.0         NaN         NaN          NaN
#  ..          ...          ...       ...         ...         ...          ...
#  366       364.0  9352.335231       1.0         NaN         NaN          NaN
#  367       365.0  9445.858583       1.0         NaN         NaN          NaN
#  368       366.0  9540.317169       1.0         NaN         NaN          NaN
#  369       367.0  9635.720341       1.0         NaN         NaN          NaN
#  370       368.0  9732.077544       1.0         NaN         NaN          NaN
#
#        سه ماه سوم  سه ماه چهارم
# ...

# %%
excel_sheets['Sheet1']
# Out:
#      Unnamed: 0        START  Gain/day  Unnamed: 3  سه ماه اول   سه ماه دوم  \
# 0           NaN   250.000000       1.0         NaN   618.27975  1513.939999
# 1           NaN          NaN       NaN         NaN         NaN          NaN
# 2           NaN          NaN       NaN         NaN         NaN          NaN
# 3           1.0   252.500000       1.0         NaN         NaN          NaN
# 4           2.0   255.025000       1.0         NaN         NaN          NaN
# ..          ...          ...       ...         ...         ...          ...
# 366       364.0  9352.335231       1.0         NaN         NaN          NaN
# 367       365.0  9445.858583       1.0         NaN         NaN          NaN
# 368       366.0  9540.317169       1.0         NaN         NaN          NaN
# 369       367.0  9635.720341       1.0         NaN         NaN          NaN
# 370       368.0  9732.077544       1.0         NaN         NaN          NaN
#
#       سه ماه سوم  سه ماه چهارم
# ...

# %% [markdown]
# # out put excel in pandas

# %%
tables[17].to_excel('table17.xlsx' , sheet_name='first_sheet' , index=False)

# %% [markdown]
# # out put sql in pandas

# %%
from sqlalchemy import create_engine

# %%
temp_db=create_engine('sqlite:///:memory:')

# %%
pop =tables[2]

# %%
pop.to_sql(name='poopulations' , con=temp_db)
# Out:
# 9

# %% [markdown]
# # input sql in pandas

# %%
pd.read_sql(sql='poopulations' , con= temp_db)
# Out:
#    index                              Region  2022 (percent)  2030 (percent)  \
# 0      0                  Sub-Saharan Africa  1,152 (14.51%)  1,401 (16.46%)
# 1      1    Northern Africa and Western Asia     549 (6.91%)     617 (7.25%)
# 2      2      Central Asia and Southern Asia  2,075 (26.13%)  2,248 (26.41%)
# 3      3  Eastern Asia and Southeastern Asia  2,342 (29.49%)  2,372 (27.87%)
# 4      4         Europe and Northern America  1,120 (14.10%)  1,129 (13.26%)
# 5      5     Latin America and the Caribbean     658 (8.29%)     695 (8.17%)
# 6      6           Australia and New Zealand      31 (0.39%)      34 (0.40%)
# 7      7                             Oceania      14 (0.18%)      15 (0.18%)
# 8      8                               World            7942            8512
#
#    2050 (percent)
# 0  2,094 (21.62%)
# 1     771 (7.96%)
# 2  2,575 (26.58%)
# 3  2,317 (23.92%)
# 4  1,125 (11.61%)
# 5     749 (7.73%)
# 6      38 (0.39%)
# 7      20 (0.21%)
# 8            9687

# %%
pd.read_sql_query(sql='SELECT Region FROM poopulations' , con=temp_db)
# Out:
#                                Region
# 0                  Sub-Saharan Africa
# 1    Northern Africa and Western Asia
# 2      Central Asia and Southern Asia
# 3  Eastern Asia and Southeastern Asia
# 4         Europe and Northern America
# 5     Latin America and the Caribbean
# 6           Australia and New Zealand
# 7                             Oceania
# 8                               World
