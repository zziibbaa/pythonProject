# %%
pip install jupyterlab-git
# Out:
# ...
#    ---------------------------------------- 0.0/367.7 kB ? eta -:--:--
#    ---------------------------------------- 0.0/367.7 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/367.7 kB 640.0 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/367.7 kB 388.9 kB/s eta 0:00:01
#    ---- ---------------------------------- 41.0/367.7 kB 388.9 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/367.7 kB 476.3 kB/s eta 0:00:01
#    --------- ----------------------------- 92.2/367.7 kB 476.3 kB/s eta 0:00:01
#    ----------- -------------------------- 112.6/367.7 kB 409.6 kB/s eta 0:00:01
#    -------------- ----------------------- 143.4/367.7 kB 425.3 kB/s eta 0:00:01
#    ----------------- -------------------- 174.1/367.7 kB 455.1 kB/s eta 0:00:01
#    -------------------- ----------------- 194.6/367.7 kB 471.4 kB/s eta 0:00:01
#    -------------------- ----------------- 194.6/367.7 kB 471.4 kB/s eta 0:00:01
# ...

# %%
! pip install jupyterlab-git

# %%
help('git')
# Out:
# Help on package git:
#
# NAME
#     git
#
# DESCRIPTION
#     # __init__.py
#     # Copyright (C) 2008, 2009 Michael Trier (mtrier@gmail.com) and contributors
#     #
#     # This module is part of GitPython and is released under
#     # the BSD License: https://opensource.org/license/bsd-3-clause/
#     # flake8: noqa
#     # @PydevCodeAnalysisIgnore
#
# PACKAGE CONTENTS
#     cmd
#     compat
#     config
#     db
#     diff
#     exc
#     index (package)
#     objects (package)
#     refs (package)
#     remote
#     repo (package)
#     types
#     util
#
# SUBMODULES
#     base
#     fun
#     head
#     log
#     reference
#     symbolic
#     tag
#     typ
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         git.exc.GitError
#             git.exc.CacheError
#                 git.exc.UnmergedEntriesError
#             git.exc.CheckoutError
#             git.exc.CommandError
#                 git.exc.GitCommandError
# ...

# %%
jupyter lab
# Out:
#   Cell In[6], line 1
#     jupyter lab
#             ^
# SyntaxError: invalid syntax
